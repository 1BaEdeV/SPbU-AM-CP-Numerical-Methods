# %%
from funcs import *
from complmethods import *
# Параметры интегрирования
a, b = 1.7, 3.2
alpha,beta = 0 , 1/4
print("Анализ квадратурных формул для функции:")
print("f(x) = 3*cos(0.5*x)*exp(x/4) + 5*sin(2.5*x)*exp(-x/3) + 2*x")
print(f"на интервале [{a}, {b}]")

# Сравнение всех методов с построением графика
compare_integration_methods(a, b, max_parts=60)
# Out:
# Анализ квадратурных формул для функции:
# f(x) = 3*cos(0.5*x)*exp(x/4) + 5*sin(2.5*x)*exp(-x/3) + 2*x
# на интервале [1.7, 3.2]
# Точное значение интеграла (вычислено): 9.312185141784799
# Сравнение методов для различного количества разбиений:
# Метод                     n=10            n=50            n=100
# ----------------------------------------------------------------------
# Левые прямоугольники      3.04e-01        6.05e-02        3.03e-02
# Правые прямоугольники     2.99e-01        6.01e-02        3.00e-02
# Средние прямоугольники    1.12e-03        5.19e-05        8.83e-05
# Трапеции                  2.54e-03        1.98e-04        1.25e-04
# Симпсон                   1.00e-01        2.00e-02        9.94e-03

# %%
"""Выполнение задания 2.2 - метод Гаусса с оценкой погрешности Ричардсоном"""

eps= 1e-06

richardson(gauss, f, a, b, alpha, beta, eps)
# Out:
# [np.float64(11.839372800320394), np.float64(11.839336156224348), np.float64(11.83933566604124)]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       1 """Выполнение задания 2.2 - метод Гаусса с оценкой погрешности Ричардсоном"""
#       3 eps= 1e-06
# ----> 5 richardson(gauss, f, a, b, alpha, beta, eps)
#
# File ~/Рабочий стол/AM-CP/Numerical-Methods/SPbU-AM-CP-Numerical-Methods/Решение_Интергралов/funcs.py:66, in richardson(quad, f, a, b, alpha, beta, eps, min_part, max_part)
#      64 values = [quad(f, a, b, alpha, beta, parts=2 ** i * min_part) for i in range(r + 1)]
#      65 print(values)
# ---> 66 print(len(values))
#      67 # Оценка скорости сходимости по Эйткену
#      68 if len(values) >= 3:
#
# TypeError: 'float' object is not callable

# %%
# Демонстрация анализа погрешности квадратурных формул
# Параметры интегрирования
a, b = 1.7, 3.2
al,bet = 0, 1/4
print("Анализ квадратурных формул для функции:")
print("f(x) = 3*cos(0.5*x)*exp(x/4) + 5*sin(2.5*x)*exp(-x/3) + 2*x")
print(f"на интервале [{a}, {b}]")

# Сравнение всех методов с построением графика
compare_integration_methods(a, b, max_parts=60)
# Out:
# Анализ квадратурных формул для функции:
# f(x) = 3*cos(0.5*x)*exp(x/4) + 5*sin(2.5*x)*exp(-x/3) + 2*x
# на интервале [1.7, 3.2]
# Точное значение интеграла (вычислено): 9.312185141784799
# Сравнение методов для различного количества разбиений:
# Метод                     n=10            n=50            n=100
# ----------------------------------------------------------------------
# Левые прямоугольники      3.04e-01        6.05e-02        3.03e-02
# Правые прямоугольники     2.99e-01        6.01e-02        3.00e-02
# Средние прямоугольники    1.12e-03        5.19e-05        8.83e-05
# Трапеции                  2.54e-03        1.98e-04        1.25e-04
# Симпсон                   1.00e-01        2.00e-02        9.94e-03

# %%
# Кастомизированное сравнение выбранных методов
"""Выполнение задания 2.2 - метод Гаусса с оценкой погрешности Ричардсоном"""
eps = 1e-6

richardson(gaus, f, a, b, al, bet, eps)
# Out:
# [np.float64(11.839372800320394), np.float64(11.839336156224348), np.float64(11.83933566604124)]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       2 """Выполнение задания 2.2 - метод Гаусса с оценкой погрешности Ричардсоном"""
#       3 eps = 1e-6
# ----> 5 richardson(gaus, f, a, b, al, bet, eps)
#
# File ~/Рабочий стол/AM-CP/Numerical-Methods/SPbU-AM-CP-Numerical-Methods/Решение_Интергралов/funcs.py:66, in richardson(quad, f, a, b, alpha, beta, eps, min_part, max_part)
#      64 values = [quad(f, a, b, alpha, beta, parts=2 ** i * min_part) for i in range(r + 1)]
#      65 print(values)
# ---> 66 print(len(values))
#      67 # Оценка скорости сходимости по Эйткену
#      68 if len(values) >= 3:
#
# TypeError: 'float' object is not callable
